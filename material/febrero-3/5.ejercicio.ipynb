# %% [markdown]
# # 🚧 **Manos a la obra**:
# - Ahora tienen todas las herramientas.
# - Una empresa les ha dicho de manera muy general la configuracion operacional de sus sistema.
# - Ustedes, como los curiosos cientificos que son, desean
# - Han recibido la siguiente informacion y desean hacer un modelo explorativo:
# - Desean modelar un sistema que produce
